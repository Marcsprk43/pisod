# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
img = cv2.imread("/Users/gerrie/Documents/UAS4Stem/images/Oskosh-max.png", cv2.IMREAD_COLOR)

# %%
imS = cv2.resize(img, (int(img.shape[0]/2), int(img.shape[1]/2)) )

# %%
cv2.imshow('image',imS)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (1830, 1726, 3)

# %%
import dronekit
from pymavlink import mavutil
import time

# %%
vehicle = dronekit.connect('/dev/cu.usbmodem11201')
# Out:
# WARNING:autopilot:GCS Failsafe Cleared

# %%
mv_msg = vehicle.message_factory.request_data_stream_encode(0,0,mavutil.mavlink.MAV_DATA_STREAM_RAW_CONTROLLER,30,1)

# %%
vehicle.send_mavlink(mv_msg)

# %%
while (1):
    time.sleep(.03)
    roll = vehicle._roll
    pitch = vehicle._pitch
    print('Roll: {} Pitch: {}'.format(roll, pitch))
# Out:
# Roll: 0.06490156799554825 Pitch: 0.02272074855864048
# Roll: 0.06490156799554825 Pitch: 0.02272074855864048
# Roll: 0.06490156799554825 Pitch: 0.02272074855864048
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.06487425416707993 Pitch: 0.02251022309064865
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# Roll: 0.0647115632891655 Pitch: 0.022328315302729607
# ...

# %%
import pickle

# %%
import pandas as pd

# %%
df = pickle.load(open("RollPitch.p", 'rb'))

# %%
import matplotlib.pyplot as plt

# %%
df[['AHRS_Roll', 'ATT_Roll']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>
